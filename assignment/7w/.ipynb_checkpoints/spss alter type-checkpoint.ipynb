# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('train.csv')
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# #### 数据清理

# %%
ALTER TYPE ESM1date (ADATE10).

# %%
for x in range(205):
    print 'ALTER TYPE '+'ESM_A_'+str(x)+'time'+' (TIME8)'
    print
# Out:
# ALTER TYPE ESM_A_0time (TIME8)
#
# ALTER TYPE ESM_A_1time (TIME8)
#
# ALTER TYPE ESM_A_2time (TIME8)
#
# ALTER TYPE ESM_A_3time (TIME8)
#
# ALTER TYPE ESM_A_4time (TIME8)
#
# ALTER TYPE ESM_A_5time (TIME8)
#
# ALTER TYPE ESM_A_6time (TIME8)
#
# ALTER TYPE ESM_A_7time (TIME8)
#
# ALTER TYPE ESM_A_8time (TIME8)
#
# ALTER TYPE ESM_A_9time (TIME8)
#
# ALTER TYPE ESM_A_10time (TIME8)
#
# ALTER TYPE ESM_A_11time (TIME8)
#
# ALTER TYPE ESM_A_12time (TIME8)
#
# ALTER TYPE ESM_A_13time (TIME8)
#
# ALTER TYPE ESM_A_14time (TIME8)
#
# ALTER TYPE ESM_A_15time (TIME8)
#
# ALTER TYPE ESM_A_16time (TIME8)
#
# ALTER TYPE ESM_A_17time (TIME8)
#
# ALTER TYPE ESM_A_18time (TIME8)
#
# ALTER TYPE ESM_A_19time (TIME8)
#
# ALTER TYPE ESM_A_20time (TIME8)
#
# ALTER TYPE ESM_A_21time (TIME8)
#
# ALTER TYPE ESM_A_22time (TIME8)
#
# ALTER TYPE ESM_A_23time (TIME8)
#
# ALTER TYPE ESM_A_24time (TIME8)
#
# ALTER TYPE ESM_A_25time (TIME8)
#
# ALTER TYPE ESM_A_26time (TIME8)
#
# ALTER TYPE ESM_A_27time (TIME8)
#
# ...

# %%
for x in range(205):
    print 'ALTER TYPE '+'ESM_A_'+str(x)+'date'+' (ADATE10)'
    print
# Out:
# ALTER TYPE ESM_A_0date (ADATE10)
#
# ALTER TYPE ESM_A_1date (ADATE10)
#
# ALTER TYPE ESM_A_2date (ADATE10)
#
# ALTER TYPE ESM_A_3date (ADATE10)
#
# ALTER TYPE ESM_A_4date (ADATE10)
#
# ALTER TYPE ESM_A_5date (ADATE10)
#
# ALTER TYPE ESM_A_6date (ADATE10)
#
# ALTER TYPE ESM_A_7date (ADATE10)
#
# ALTER TYPE ESM_A_8date (ADATE10)
#
# ALTER TYPE ESM_A_9date (ADATE10)
#
# ALTER TYPE ESM_A_10date (ADATE10)
#
# ALTER TYPE ESM_A_11date (ADATE10)
#
# ALTER TYPE ESM_A_12date (ADATE10)
#
# ALTER TYPE ESM_A_13date (ADATE10)
#
# ALTER TYPE ESM_A_14date (ADATE10)
#
# ALTER TYPE ESM_A_15date (ADATE10)
#
# ALTER TYPE ESM_A_16date (ADATE10)
#
# ALTER TYPE ESM_A_17date (ADATE10)
#
# ALTER TYPE ESM_A_18date (ADATE10)
#
# ALTER TYPE ESM_A_19date (ADATE10)
#
# ALTER TYPE ESM_A_20date (ADATE10)
#
# ALTER TYPE ESM_A_21date (ADATE10)
#
# ALTER TYPE ESM_A_22date (ADATE10)
#
# ALTER TYPE ESM_A_23date (ADATE10)
#
# ALTER TYPE ESM_A_24date (ADATE10)
#
# ALTER TYPE ESM_A_25date (ADATE10)
#
# ...

# %%
for x in range(36):
    print 'ALTER TYPE '+ 'ESM'+str(x)+'time'+' (TIME8)'
    print
# Out:
# ALTER TYPE ESM0time (TIME8)
#
# ALTER TYPE ESM1time (TIME8)
#
# ALTER TYPE ESM2time (TIME8)
#
# ALTER TYPE ESM3time (TIME8)
#
# ALTER TYPE ESM4time (TIME8)
#
# ALTER TYPE ESM5time (TIME8)
#
# ALTER TYPE ESM6time (TIME8)
#
# ALTER TYPE ESM7time (TIME8)
#
# ALTER TYPE ESM8time (TIME8)
#
# ALTER TYPE ESM9time (TIME8)
#
# ALTER TYPE ESM10time (TIME8)
#
# ALTER TYPE ESM11time (TIME8)
#
# ALTER TYPE ESM12time (TIME8)
#
# ALTER TYPE ESM13time (TIME8)
#
# ALTER TYPE ESM14time (TIME8)
#
# ALTER TYPE ESM15time (TIME8)
#
# ALTER TYPE ESM16time (TIME8)
#
# ALTER TYPE ESM17time (TIME8)
#
# ALTER TYPE ESM18time (TIME8)
#
# ALTER TYPE ESM19time (TIME8)
#
# ALTER TYPE ESM20time (TIME8)
#
# ALTER TYPE ESM21time (TIME8)
#
# ALTER TYPE ESM22time (TIME8)
#
# ALTER TYPE ESM23time (TIME8)
#
# ALTER TYPE ESM24time (TIME8)
#
# ALTER TYPE ESM25time (TIME8)
#
# ALTER TYPE ESM26time (TIME8)
#
# ALTER TYPE ESM27time (TIME8)
#
# ALTER TYPE ESM28time (TIME8)
#
# ALTER TYPE ESM29time (TIME8)
#
# ...

# %%
for x in range(36):
    print 'ALTER TYPE '+ 'ESM'+str(x)+'date'+' (ADATE10)'
    print
# Out:
# ALTER TYPE ESM0date (ADATE10)
#
# ALTER TYPE ESM1date (ADATE10)
#
# ALTER TYPE ESM2date (ADATE10)
#
# ALTER TYPE ESM3date (ADATE10)
#
# ALTER TYPE ESM4date (ADATE10)
#
# ALTER TYPE ESM5date (ADATE10)
#
# ALTER TYPE ESM6date (ADATE10)
#
# ALTER TYPE ESM7date (ADATE10)
#
# ALTER TYPE ESM8date (ADATE10)
#
# ALTER TYPE ESM9date (ADATE10)
#
# ALTER TYPE ESM10date (ADATE10)
#
# ALTER TYPE ESM11date (ADATE10)
#
# ALTER TYPE ESM12date (ADATE10)
#
# ALTER TYPE ESM13date (ADATE10)
#
# ALTER TYPE ESM14date (ADATE10)
#
# ALTER TYPE ESM15date (ADATE10)
#
# ALTER TYPE ESM16date (ADATE10)
#
# ALTER TYPE ESM17date (ADATE10)
#
# ALTER TYPE ESM18date (ADATE10)
#
# ALTER TYPE ESM19date (ADATE10)
#
# ALTER TYPE ESM20date (ADATE10)
#
# ALTER TYPE ESM21date (ADATE10)
#
# ALTER TYPE ESM22date (ADATE10)
#
# ALTER TYPE ESM23date (ADATE10)
#
# ALTER TYPE ESM24date (ADATE10)
#
# ALTER TYPE ESM25date (ADATE10)
#
# ALTER TYPE ESM26date (ADATE10)
#
# ALTER TYPE ESM27date (ADATE10)
#
# ...
